# %% [markdown]
# # Sprint 1: Foundational Setup
#
# ## Task 1 (CIR-8): Load and Validate all Datasets

# %%
import pandas as pd
import numpy as np
import os
import logging

# Plots
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("logs/CIR-8.log"),
        logging.StreamHandler()
    ]
)

# %%
# CSVs Directory 
data_path = "../04_ANN/CSV/exports/split_set/without_multiple_rows"
all_files = os.listdir(data_path)

logging.info("++++++++++++++++++++++++++++++++++++++++++")
logging.info("Start Loading Dataframes.")

# Load CSVs into a dictionary of dataframes
dataframes = {}
for file in all_files:
    if file.endswith(".csv"):
        var_name = file.replace(".csv", "").replace("-", "_")
        logging.info(f"Loading... -> {file}")
        dataframes[var_name] = pd.read_csv(os.path.join(data_path, file)).astype('float32')

# Log loaded datasets
for var_name, df in dataframes.items():
    globals()[var_name] = df
    logging.info(f"{var_name} loaded successfully with shape {df.shape}")
logging.info("Load Complete.")
logging.info("++++++++++++++++++++++++++++++++++++++++++")
# Out:
# 2025-03-23 15:55:23,866 - INFO - ++++++++++++++++++++++++++++++++++++++++++
# 2025-03-23 15:55:23,868 - INFO - Start Loading Dataframes.
# 2025-03-23 15:55:23,869 - INFO - Loading... -> o1_X_external.csv
# 2025-03-23 15:55:30,749 - INFO - Loading... -> o1_X_test.csv
# 2025-03-23 15:55:31,275 - INFO - Loading... -> o1_X_train.csv
# 2025-03-23 15:55:35,267 - INFO - Loading... -> o1_X_validate.csv
# 2025-03-23 15:55:35,779 - INFO - Loading... -> o1_y_external_los.csv
# 2025-03-23 15:55:35,832 - INFO - Loading... -> o1_y_external_mortality.csv
# 2025-03-23 15:55:35,868 - INFO - Loading... -> o1_y_test_los.csv
# 2025-03-23 15:55:35,883 - INFO - Loading... -> o1_y_test_mortality.csv
# 2025-03-23 15:55:35,895 - INFO - Loading... -> o1_y_train_los.csv
# 2025-03-23 15:55:35,945 - INFO - Loading... -> o1_y_train_mortality.csv
# 2025-03-23 15:55:35,964 - INFO - Loading... -> o1_y_validate_los.csv
# 2025-03-23 15:55:35,987 - INFO - Loading... -> o1_y_validate_mortality.csv
# 2025-03-23 15:55:35,999 - INFO - Loading... -> o2_X_external.csv
# 2025-03-23 15:55:39,647 - INFO - Loading... -> o2_X_test.csv
# 2025-03-23 15:55:39,941 - INFO - Loading... -> o2_X_train.csv
# 2025-03-23 15:55:41,951 - INFO - Loading... -> o2_X_validate.csv
# 2025-03-23 15:55:42,246 - INFO - Loading... -> o2_y_external_los.csv
# 2025-03-23 15:55:42,282 - INFO - Loading... -> o2_y_external_mortality.csv
# 2025-03-23 15:55:42,307 - INFO - Loading... -> o2_y_test_los.csv
# 2025-03-23 15:55:42,327 - INFO - Loading... -> o2_y_test_mortality.csv
# 2025-03-23 15:55:42,340 - INFO - Loading... -> o2_y_train_los.csv
# 2025-03-23 15:55:42,365 - INFO - Loading... -> o2_y_train_mortality.csv
# 2025-03-23 15:55:42,383 - INFO - Loading... -> o2_y_validate_los.csv
# 2025-03-23 15:55:42,399 - INFO - Loading... -> o2_y_validate_mortality.csv
# 2025-03-23 15:55:42,414 - INFO - Loading... -> o3_X_external.csv
# 2025-03-23 15:55:44,657 - INFO - Loading... -> o3_X_test.csv
# 2025-03-23 15:55:44,853 - INFO - Loading... -> o3_X_train.csv
# 2025-03-23 15:55:46,147 - INFO - Loading... -> o3_X_validate.csv
# 2025-03-23 15:55:46,346 - INFO - Loading... -> o3_y_external_los.csv
# 2025-03-23 15:55:46,376 - INFO - Loading... -> o3_y_external_mortality.csv
# 2025-03-23 15:55:46,396 - INFO - Loading... -> o3_y_test_los.csv
# 2025-03-23 15:55:46,406 - INFO - Loading... -> o3_y_test_mortality.csv
# 2025-03-23 15:55:46,415 - INFO - Loading... -> o3_y_train_los.csv
# 2025-03-23 15:55:46,436 - INFO - Loading... -> o3_y_train_mortality.csv
# 2025-03-23 15:55:46,445 - INFO - Loading... -> o3_y_validate_los.csv
# 2025-03-23 15:55:46,461 - INFO - Loading... -> o3_y_validate_mortality.csv
# 2025-03-23 15:55:46,471 - INFO - Loading... -> o4_X_external.csv
# 2025-03-23 15:55:48,190 - INFO - Loading... -> o4_X_test.csv
# 2025-03-23 15:55:48,351 - INFO - Loading... -> o4_X_train.csv
# 2025-03-23 15:55:49,332 - INFO - Loading... -> o4_X_validate.csv
# 2025-03-23 15:55:49,483 - INFO - Loading... -> o4_y_external_los.csv
# 2025-03-23 15:55:49,506 - INFO - Loading... -> o4_y_external_mortality.csv
# 2025-03-23 15:55:49,528 - INFO - Loading... -> o4_y_test_los.csv
# 2025-03-23 15:55:49,538 - INFO - Loading... -> o4_y_test_mortality.csv
# 2025-03-23 15:55:49,550 - INFO - Loading... -> o4_y_train_los.csv
# 2025-03-23 15:55:49,569 - INFO - Loading... -> o4_y_train_mortality.csv
# 2025-03-23 15:55:49,578 - INFO - Loading... -> o4_y_validate_los.csv
# 2025-03-23 15:55:49,599 - INFO - Loading... -> o4_y_validate_mortality.csv
# 2025-03-23 15:55:49,611 - INFO - o1_X_external loaded successfully with shape (234720, 345)
# 2025-03-23 15:55:49,611 - INFO - o1_X_test loaded successfully with shape (15312, 345)
# 2025-03-23 15:55:49,612 - INFO - o1_X_train loaded successfully with shape (122496, 345)
# 2025-03-23 15:55:49,614 - INFO - o1_X_validate loaded successfully with shape (15312, 345)
# 2025-03-23 15:55:49,615 - INFO - o1_y_external_los loaded successfully with shape (234720, 1)
# 2025-03-23 15:55:49,616 - INFO - o1_y_external_mortality loaded successfully with shape (234720, 1)
# 2025-03-23 15:55:49,616 - INFO - o1_y_test_los loaded successfully with shape (15312, 1)
# 2025-03-23 15:55:49,618 - INFO - o1_y_test_mortality loaded successfully with shape (15312, 1)
# 2025-03-23 15:55:49,619 - INFO - o1_y_train_los loaded successfully with shape (122496, 1)
# 2025-03-23 15:55:49,620 - INFO - o1_y_train_mortality loaded successfully with shape (122496, 1)
# 2025-03-23 15:55:49,621 - INFO - o1_y_validate_los loaded successfully with shape (15312, 1)
# 2025-03-23 15:55:49,621 - INFO - o1_y_validate_mortality loaded successfully with shape (15312, 1)
# 2025-03-23 15:55:49,623 - INFO - o2_X_external loaded successfully with shape (117360, 345)
# 2025-03-23 15:55:49,623 - INFO - o2_X_test loaded successfully with shape (7656, 345)
# 2025-03-23 15:55:49,624 - INFO - o2_X_train loaded successfully with shape (61248, 345)
# 2025-03-23 15:55:49,624 - INFO - o2_X_validate loaded successfully with shape (7656, 345)
# 2025-03-23 15:55:49,626 - INFO - o2_y_external_los loaded successfully with shape (117360, 1)
# 2025-03-23 15:55:49,628 - INFO - o2_y_external_mortality loaded successfully with shape (117360, 1)
# 2025-03-23 15:55:49,628 - INFO - o2_y_test_los loaded successfully with shape (7656, 1)
# 2025-03-23 15:55:49,629 - INFO - o2_y_test_mortality loaded successfully with shape (7656, 1)
# 2025-03-23 15:55:49,630 - INFO - o2_y_train_los loaded successfully with shape (61248, 1)
# 2025-03-23 15:55:49,631 - INFO - o2_y_train_mortality loaded successfully with shape (61248, 1)
# 2025-03-23 15:55:49,632 - INFO - o2_y_validate_los loaded successfully with shape (7656, 1)
# 2025-03-23 15:55:49,632 - INFO - o2_y_validate_mortality loaded successfully with shape (7656, 1)
# 2025-03-23 15:55:49,634 - INFO - o3_X_external loaded successfully with shape (78240, 345)
# 2025-03-23 15:55:49,635 - INFO - o3_X_test loaded successfully with shape (5104, 345)
# 2025-03-23 15:55:49,636 - INFO - o3_X_train loaded successfully with shape (40832, 345)
# 2025-03-23 15:55:49,637 - INFO - o3_X_validate loaded successfully with shape (5104, 345)
# 2025-03-23 15:55:49,638 - INFO - o3_y_external_los loaded successfully with shape (78240, 1)
# 2025-03-23 15:55:49,639 - INFO - o3_y_external_mortality loaded successfully with shape (78240, 1)
# 2025-03-23 15:55:49,639 - INFO - o3_y_test_los loaded successfully with shape (5104, 1)
# 2025-03-23 15:55:49,640 - INFO - o3_y_test_mortality loaded successfully with shape (5104, 1)
# 2025-03-23 15:55:49,641 - INFO - o3_y_train_los loaded successfully with shape (40832, 1)
# 2025-03-23 15:55:49,643 - INFO - o3_y_train_mortality loaded successfully with shape (40832, 1)
# 2025-03-23 15:55:49,644 - INFO - o3_y_validate_los loaded successfully with shape (5104, 1)
# 2025-03-23 15:55:49,644 - INFO - o3_y_validate_mortality loaded successfully with shape (5104, 1)
# 2025-03-23 15:55:49,645 - INFO - o4_X_external loaded successfully with shape (58680, 345)
# 2025-03-23 15:55:49,646 - INFO - o4_X_test loaded successfully with shape (3828, 345)
# 2025-03-23 15:55:49,647 - INFO - o4_X_train loaded successfully with shape (30624, 345)
# 2025-03-23 15:55:49,648 - INFO - o4_X_validate loaded successfully with shape (3828, 345)
# 2025-03-23 15:55:49,649 - INFO - o4_y_external_los loaded successfully with shape (58680, 1)
# 2025-03-23 15:55:49,649 - INFO - o4_y_external_mortality loaded successfully with shape (58680, 1)
# 2025-03-23 15:55:49,650 - INFO - o4_y_test_los loaded successfully with shape (3828, 1)
# 2025-03-23 15:55:49,651 - INFO - o4_y_test_mortality loaded successfully with shape (3828, 1)
# 2025-03-23 15:55:49,651 - INFO - o4_y_train_los loaded successfully with shape (30624, 1)
# 2025-03-23 15:55:49,653 - INFO - o4_y_train_mortality loaded successfully with shape (30624, 1)
# 2025-03-23 15:55:49,654 - INFO - o4_y_validate_los loaded successfully with shape (3828, 1)
# 2025-03-23 15:55:49,654 - INFO - o4_y_validate_mortality loaded successfully with shape (3828, 1)
# 2025-03-23 15:55:49,655 - INFO - Load Complete.
# 2025-03-23 15:55:49,656 - INFO - ++++++++++++++++++++++++++++++++++++++++++

# %%
logging.info("++++++++++++++++++++++++++++++++++++++++++")
logging.info("Check Datatypes...")
for name, df in dataframes.items():
    logging.info(f"{name} types:\n{df.dtypes.value_counts()}")
logging.info("Check Complete.")
logging.info("++++++++++++++++++++++++++++++++++++++++++")
# Out:
# 2025-03-23 15:55:49,666 - INFO - ++++++++++++++++++++++++++++++++++++++++++
# 2025-03-23 15:55:49,668 - INFO - Check Datatypes...
# 2025-03-23 15:55:49,675 - INFO - o1_X_external types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,678 - INFO - o1_X_test types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,679 - INFO - o1_X_train types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,681 - INFO - o1_X_validate types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,683 - INFO - o1_y_external_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,684 - INFO - o1_y_external_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,686 - INFO - o1_y_test_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,688 - INFO - o1_y_test_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,690 - INFO - o1_y_train_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,691 - INFO - o1_y_train_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,695 - INFO - o1_y_validate_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,696 - INFO - o1_y_validate_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,698 - INFO - o2_X_external types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,700 - INFO - o2_X_test types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,702 - INFO - o2_X_train types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,704 - INFO - o2_X_validate types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,705 - INFO - o2_y_external_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,707 - INFO - o2_y_external_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,708 - INFO - o2_y_test_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,712 - INFO - o2_y_test_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,713 - INFO - o2_y_train_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,715 - INFO - o2_y_train_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,718 - INFO - o2_y_validate_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,719 - INFO - o2_y_validate_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,721 - INFO - o3_X_external types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,722 - INFO - o3_X_test types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,724 - INFO - o3_X_train types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,726 - INFO - o3_X_validate types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,728 - INFO - o3_y_external_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,729 - INFO - o3_y_external_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,731 - INFO - o3_y_test_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,734 - INFO - o3_y_test_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,735 - INFO - o3_y_train_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,737 - INFO - o3_y_train_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,738 - INFO - o3_y_validate_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,740 - INFO - o3_y_validate_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,741 - INFO - o4_X_external types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,744 - INFO - o4_X_test types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,745 - INFO - o4_X_train types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,747 - INFO - o4_X_validate types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 15:55:49,750 - INFO - o4_y_external_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,751 - INFO - o4_y_external_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,753 - INFO - o4_y_test_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,754 - INFO - o4_y_test_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,755 - INFO - o4_y_train_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,757 - INFO - o4_y_train_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,759 - INFO - o4_y_validate_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,760 - INFO - o4_y_validate_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 15:55:49,761 - INFO - Check Complete.
# 2025-03-23 15:55:49,762 - INFO - ++++++++++++++++++++++++++++++++++++++++++

# %%
logging.info("++++++++++++++++++++++++++++++++++++++++++")
logging.info("Calculate missing values...")
for name, df in dataframes.items():
    missing_total = df.isnull().sum().sum()
    missing_cols = df.columns[df.isnull().any()].tolist()
    logging.info(f"{name}: {missing_total} missing values across {len(missing_cols)} columns")
logging.info("Missing values calculation complete.")
logging.info("++++++++++++++++++++++++++++++++++++++++++")
# Out:
# 2025-03-23 15:55:49,771 - INFO - ++++++++++++++++++++++++++++++++++++++++++
# 2025-03-23 15:55:49,772 - INFO - Calculate missing values...
# 2025-03-23 15:55:49,948 - INFO - o1_X_external: 39527616 missing values across 308 columns
# 2025-03-23 15:55:49,963 - INFO - o1_X_test: 1985664 missing values across 292 columns
# 2025-03-23 15:55:50,053 - INFO - o1_X_train: 15876288 missing values across 304 columns
# 2025-03-23 15:55:50,067 - INFO - o1_X_validate: 2007696 missing values across 296 columns
# 2025-03-23 15:55:50,070 - INFO - o1_y_external_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,072 - INFO - o1_y_external_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,075 - INFO - o1_y_test_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,077 - INFO - o1_y_test_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,079 - INFO - o1_y_train_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,081 - INFO - o1_y_train_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,083 - INFO - o1_y_validate_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,085 - INFO - o1_y_validate_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,169 - INFO - o2_X_external: 19763572 missing values across 308 columns
# 2025-03-23 15:55:50,178 - INFO - o2_X_test: 992832 missing values across 292 columns
# 2025-03-23 15:55:50,224 - INFO - o2_X_train: 7938144 missing values across 304 columns
# 2025-03-23 15:55:50,233 - INFO - o2_X_validate: 1003848 missing values across 296 columns
# 2025-03-23 15:55:50,235 - INFO - o2_y_external_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,237 - INFO - o2_y_external_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,239 - INFO - o2_y_test_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,240 - INFO - o2_y_test_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,243 - INFO - o2_y_train_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,245 - INFO - o2_y_train_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,247 - INFO - o2_y_validate_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,249 - INFO - o2_y_validate_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,306 - INFO - o3_X_external: 13175808 missing values across 308 columns
# 2025-03-23 15:55:50,313 - INFO - o3_X_test: 661888 missing values across 292 columns
# 2025-03-23 15:55:50,345 - INFO - o3_X_train: 5292096 missing values across 304 columns
# 2025-03-23 15:55:50,352 - INFO - o3_X_validate: 669232 missing values across 296 columns
# 2025-03-23 15:55:50,354 - INFO - o3_y_external_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,356 - INFO - o3_y_external_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,358 - INFO - o3_y_test_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,360 - INFO - o3_y_test_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,361 - INFO - o3_y_train_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,363 - INFO - o3_y_train_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,365 - INFO - o3_y_validate_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,367 - INFO - o3_y_validate_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,411 - INFO - o4_X_external: 9881900 missing values across 308 columns
# 2025-03-23 15:55:50,417 - INFO - o4_X_test: 496416 missing values across 292 columns
# 2025-03-23 15:55:50,448 - INFO - o4_X_train: 3969072 missing values across 304 columns
# 2025-03-23 15:55:50,454 - INFO - o4_X_validate: 501924 missing values across 296 columns
# 2025-03-23 15:55:50,457 - INFO - o4_y_external_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,459 - INFO - o4_y_external_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,461 - INFO - o4_y_test_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,463 - INFO - o4_y_test_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,464 - INFO - o4_y_train_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,467 - INFO - o4_y_train_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,468 - INFO - o4_y_validate_los: 0 missing values across 0 columns
# 2025-03-23 15:55:50,469 - INFO - o4_y_validate_mortality: 0 missing values across 0 columns
# 2025-03-23 15:55:50,470 - INFO - Missing values calculation complete.
# 2025-03-23 15:55:50,471 - INFO - ++++++++++++++++++++++++++++++++++++++++++

# %%
logging.info("++++++++++++++++++++++++++++++++++++++++++")
logging.info("Calculate unique values.")
for name, df in dataframes.items():
    if 'y_' in name:
        unique_vals = df.nunique()
        logging.info(f"{name} unique target values: {unique_vals.to_dict()}")

logging.info("Unique values calculation complete.")
logging.info("++++++++++++++++++++++++++++++++++++++++++")
# Out:
# 2025-03-23 15:55:50,480 - INFO - ++++++++++++++++++++++++++++++++++++++++++
# 2025-03-23 15:55:50,481 - INFO - Calculate unique values.
# 2025-03-23 15:55:50,491 - INFO - o1_y_external_los unique target values: {'los': 830}
# 2025-03-23 15:55:50,495 - INFO - o1_y_external_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,497 - INFO - o1_y_test_los unique target values: {'los': 319}
# 2025-03-23 15:55:50,498 - INFO - o1_y_test_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,502 - INFO - o1_y_train_los unique target values: {'los': 2548}
# 2025-03-23 15:55:50,504 - INFO - o1_y_train_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,506 - INFO - o1_y_validate_los unique target values: {'los': 319}
# 2025-03-23 15:55:50,507 - INFO - o1_y_validate_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,511 - INFO - o2_y_external_los unique target values: {'los': 830}
# 2025-03-23 15:55:50,513 - INFO - o2_y_external_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,515 - INFO - o2_y_test_los unique target values: {'los': 319}
# 2025-03-23 15:55:50,516 - INFO - o2_y_test_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,518 - INFO - o2_y_train_los unique target values: {'los': 2548}
# 2025-03-23 15:55:50,520 - INFO - o2_y_train_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,521 - INFO - o2_y_validate_los unique target values: {'los': 319}
# 2025-03-23 15:55:50,523 - INFO - o2_y_validate_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,525 - INFO - o3_y_external_los unique target values: {'los': 830}
# 2025-03-23 15:55:50,527 - INFO - o3_y_external_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,528 - INFO - o3_y_test_los unique target values: {'los': 319}
# 2025-03-23 15:55:50,530 - INFO - o3_y_test_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,532 - INFO - o3_y_train_los unique target values: {'los': 2548}
# 2025-03-23 15:55:50,533 - INFO - o3_y_train_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,534 - INFO - o3_y_validate_los unique target values: {'los': 319}
# 2025-03-23 15:55:50,536 - INFO - o3_y_validate_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,538 - INFO - o4_y_external_los unique target values: {'los': 830}
# 2025-03-23 15:55:50,540 - INFO - o4_y_external_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,541 - INFO - o4_y_test_los unique target values: {'los': 319}
# 2025-03-23 15:55:50,543 - INFO - o4_y_test_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,545 - INFO - o4_y_train_los unique target values: {'los': 2548}
# 2025-03-23 15:55:50,546 - INFO - o4_y_train_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,547 - INFO - o4_y_validate_los unique target values: {'los': 319}
# 2025-03-23 15:55:50,548 - INFO - o4_y_validate_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 15:55:50,549 - INFO - Unique values calculation complete.
# 2025-03-23 15:55:50,550 - INFO - ++++++++++++++++++++++++++++++++++++++++++

# %%
summary = []
for name, df in dataframes.items():
    missing_values = df.isnull().sum().sum()
    missing_cols = df.isnull().any().sum()
    total_cells = df.shape[0] * df.shape[1]
    summary.append({
        'Dataset': name,
        'Shape': df.shape,
        'Total Missing Values': missing_values,
        'Accross Missing Columns': missing_cols,
        'Missing %': 100 * missing_values / total_cells
    })

summary_df = pd.DataFrame(summary)
# Save to file
summary_df.to_csv("CSV/exports/01_dataset_summary.csv", index=False)

# %%
percent = 7

# Dictionary of datasets for iteration
datasets = {
    "o1_X_train": o1_X_train,
    "o2_X_train": o2_X_train,
    "o3_X_train": o3_X_train,
    "o4_X_train": o4_X_train
}

# Loop through each dataset
for name, df in datasets.items():
    missing_percentage_per_row = df.isnull().mean(axis=1) * 100
    missing_rows = (missing_percentage_per_row <= percent).sum()
    total_rows, total_columns = df.shape
    percent_between = (missing_rows * 100) / total_rows

    print(f"\nDataset: {name}")
    print(f"Total Rows: {total_rows}, Total Columns: {total_columns}")
    print(f"Number of rows with missing values up to {percent}%: {missing_rows}")
    print(f"The percentage between total and missing values sets is {percent_between:.2f}%")
# Out:
# Dataset: o1_X_train
# Total Rows: 122496, Total Columns: 345
# Number of rows with missing values up to 7%: 48
# The percentage between total and missing values sets is 0.04%
#
# Dataset: o2_X_train
# Total Rows: 61248, Total Columns: 345
# Number of rows with missing values up to 7%: 24
# The percentage between total and missing values sets is 0.04%
#
# Dataset: o3_X_train
# Total Rows: 40832, Total Columns: 345
# Number of rows with missing values up to 7%: 16
# The percentage between total and missing values sets is 0.04%
#
# Dataset: o4_X_train
# Total Rows: 30624, Total Columns: 345
# Number of rows with missing values up to 7%: 12
# The percentage between total and missing values sets is 0.04%

# %% [markdown]
# ## Task 2 (CIR-9): Analyze Missingness (per row/column)

# %%
missingness_summary = []

for name, df in dataframes.items():
    if not isinstance(df, pd.DataFrame):
        continue
    
    total_cells = df.shape[0] * df.shape[1]
    total_missing = df.isnull().sum().sum()
    
    col_missing = df.isnull().mean() * 100
    row_missing = df.isnull().mean(axis=1) * 100
    
    summary = {
        'Dataset': name,
        'Shape': df.shape,
        'Total Missing Cells': total_missing,
        'Total Missing %': round(100 * total_missing / total_cells, 2),
        'Columns with Missing (%)': (col_missing > 0).sum(),
        'Max % Missing in Row': round(row_missing.max(), 2),
        'Mean % Missing in Row': round(row_missing.mean(), 2),
        'Min % Missing in Row': round(row_missing.min(), 2)
    }
    missingness_summary.append(summary)

# Create DataFrame for summary
missingness_df = pd.DataFrame(missingness_summary)

# Sort by most missing
missingness_df.sort_values("Total Missing %", ascending=False, inplace=True)

# Save to file
missingness_df.to_csv("CSV/exports/02_missingness_summary.csv", index=False)

# Show top rows, I have leave out the y_ files which are labels
display(missingness_df.head(16))
# Out:
#           Dataset          Shape  Total Missing Cells  Total Missing %  \
# 0   o1_X_external  (234720, 345)             39527616            48.81
# 12  o2_X_external  (117360, 345)             19763572            48.81
# 36  o4_X_external   (58680, 345)              9881900            48.81
# 24  o3_X_external   (78240, 345)             13175808            48.81
# 27  o3_X_validate    (5104, 345)               669232            38.01
# 3   o1_X_validate   (15312, 345)              2007696            38.01
# 15  o2_X_validate    (7656, 345)              1003848            38.01
# 39  o4_X_validate    (3828, 345)               501924            38.01
# 25      o3_X_test    (5104, 345)               661888            37.59
# 1       o1_X_test   (15312, 345)              1985664            37.59
# 13      o2_X_test    (7656, 345)               992832            37.59
# 37      o4_X_test    (3828, 345)               496416            37.59
# 26     o3_X_train   (40832, 345)              5292096            37.57
# 2      o1_X_train  (122496, 345)             15876288            37.57
# 14     o2_X_train   (61248, 345)              7938144            37.57
# 38     o4_X_train   (30624, 345)              3969072            37.57
#
#     Columns with Missing (%)  Max % Missing in Row  Mean % Missing in Row  \
# 0                        308                 89.28                  48.81
# 12                       308                 89.28                  48.81
# 36                       308                 89.28                  48.81
# 24                       308                 89.28                  48.81
# 27                       296                 78.84                  38.01
# 3                        296                 78.84                  38.01
# 15                       296                 78.84                  38.01
# 39                       296                 78.84                  38.01
# 25                       292                 80.00                  37.59
# 1                        292                 80.00                  37.59
# 13                       292                 80.00                  37.59
# 37                       292                 80.00                  37.59
# 26                       304                 81.16                  37.57
# 2                        304                 81.16                  37.57
# 14                       304                 81.16                  37.57
# 38                       304                 81.16                  37.57
#
#     Min % Missing in Row
# 0                  13.91
# 12                 13.91
# 36                 13.91
# 24                 13.91
# 27                  9.28
# 3                   9.28
# 15                  9.28
# 39                  9.28
# 25                 10.43
# 1                  10.43
# 13                 10.43
# 37                 10.43
# 26                  6.96
# 2                   6.96
# 14                  6.96
# 38                  6.96

# %% [markdown]
# ## Task 3 (CIR-10): Visualize Missingness

# %%
# Create output folder
output_dir = "figures/task3_missingness"
os.makedirs(output_dir, exist_ok=True)

# Functions for plotting
def plot_missing_heatmap(
    df, title, max_rows=200, save_path=None, suffix_filter='(Min)', cmap='Blues'
):
    filtered_cols = [col for col in df.columns if col.endswith(suffix_filter)]
    df_filtered = df[filtered_cols].head(max_rows)

    plt.figure(figsize=(16, 6))
    sns.heatmap(df_filtered.isnull(), cbar=False, cmap=cmap, yticklabels=False,
                linecolor='lightgrey', linewidths=0.001)

    plt.title(f"Missing Data Heatmap – First {max_rows} Rows\n({suffix_filter}) – {title}",
              fontsize=14, weight='bold')
    plt.xlabel("Features", fontsize=12)
    plt.ylabel("Rows", fontsize=12)
    plt.xticks(fontsize=8, rotation=90)
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.close()


def plot_column_missing_bar(
    df, title, save_path=None, top_n=40, suffix_filter='(Min)', color='#3E8ED0'
):
    filtered_cols = [col for col in df.columns if col.endswith(suffix_filter)]
    missing_perc = df[filtered_cols].isnull().mean() * 100
    missing_perc = missing_perc[missing_perc > 0].sort_values(ascending=False).head(top_n)

    plt.figure(figsize=(10, 0.4 * len(missing_perc)))
    ax = missing_perc.plot(kind='barh', color=color)

    plt.title(f"Top {len(missing_perc)} Features with Missing Values\n({suffix_filter}) – {title}",
              fontsize=14, weight='bold')
    plt.xlabel("Percentage Missing", fontsize=12)
    plt.ylabel("Feature", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=8)
    plt.grid(axis='x', linestyle='--', linewidth=0.5)
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.close()


# Filter only X datasets from the summary
top_datasets = missingness_df[
    (~missingness_df['Dataset'].str.startswith('y_')) &
    (missingness_df['Dataset'].isin(dataframes.keys()))
].head(16)['Dataset'].tolist()

# Generate plots
for dataset_name in top_datasets:
    df = dataframes.get(dataset_name)
    if df is not None:
        print(f"Generating plots for: {dataset_name}")
        heatmap_path = os.path.join(output_dir, f"{dataset_name}_heatmap.png")
        barplot_path = os.path.join(output_dir, f"{dataset_name}_barplot.png")
        
        plot_missing_heatmap(df, dataset_name, save_path=heatmap_path)
        plot_column_missing_bar(df, dataset_name, save_path=barplot_path)
    else:
        print(f"Dataset not found in dataframes: {dataset_name}")
# Out:
# Generating plots for: o1_X_external
# Generating plots for: o2_X_external
# Generating plots for: o4_X_external
# Generating plots for: o3_X_external
# Generating plots for: o3_X_validate
# Generating plots for: o1_X_validate
# Generating plots for: o2_X_validate
# Generating plots for: o4_X_validate
# Generating plots for: o3_X_test
# Generating plots for: o1_X_test
# Generating plots for: o2_X_test
# Generating plots for: o4_X_test
# Generating plots for: o3_X_train
# Generating plots for: o1_X_train
# Generating plots for: o2_X_train
# Generating plots for: o4_X_train

# %% [markdown]
# ## Task 4 (CIR-11): Define Clinical Value Ranges

# %%
# Step 1: Choose suffix
SUFFIX = '(Min)'  # or '(Mean)', etc.

# Step 2: Collect global min/max per feature
global_min_max = {}

for name, df in dataframes.items():
    if name.startswith('y_'):  # Skip target datasets
        continue
    filtered_cols = [col for col in df.columns if col.endswith(SUFFIX)]
    filtered_df = df[filtered_cols]
    
    # For each feature, collect min and max
    for col in filtered_cols:
        col_min = filtered_df[col].min(skipna=True)
        col_max = filtered_df[col].max(skipna=True)
        
        if col not in global_min_max:
            global_min_max[col] = {'min': col_min, 'max': col_max}
        else:
            global_min_max[col]['min'] = min(global_min_max[col]['min'], col_min)
            global_min_max[col]['max'] = max(global_min_max[col]['max'], col_max)

# Step 3: Convert to DataFrame
clinical_ranges_df = pd.DataFrame.from_dict(global_min_max, orient='index')
clinical_ranges_df = clinical_ranges_df.rename(columns={'min': 'Observed Min', 'max': 'Observed Max'})
clinical_ranges_df = clinical_ranges_df.sort_index()

# Save it to a CSV file
#clinical_ranges_df.to_csv("CSV/exports/03_observed_clinical_ranges.csv")

# Show a preview
clinical_ranges_df.head(10)
# Out:
#                                                 Observed Min  Observed Max
# Alanine_Aminotransferase_(ALT)_(Min)                     1.0        7510.0
# Albumin_(Min)                                            1.0           5.1
# Alkaline_Phosphatase_(Min)                               8.0        1448.0
# Ammonia_(Min)                                            2.2         130.0
# Amylase_(Min)                                            7.0        4867.0
# Anion_Gap_(Min)                                         -3.0          49.0
# Arterial_Blood_Pressure_diastolic_(mmHg)_(Min)          -2.0         355.0
# Arterial_Blood_Pressure_mean_(mmHg)_(Min)              -37.0         363.0
# Arterial_Blood_Pressure_systolic_(mmHg)_(Min)            0.0         365.0
# Asparate_Aminotransferase_(AST)_(Min)                    0.0       12652.0

# %%
labevents_df = pd.read_csv(r"..\00_Datasets\mimic-iv-3_1\icu\d_items.csv.gz")

# %%
display(labevents_df)
# Out:
#       itemid                          label                   abbreviation  \
# 0     220001                   Problem List                   Problem List
# 1     220003             ICU Admission date             ICU Admission date
# 2     220045                     Heart Rate                             HR
# 3     220046        Heart rate Alarm - High                HR Alarm - High
# 4     220047         Heart Rate Alarm - Low                 HR Alarm - Low
# ...      ...                            ...                            ...
# 4090  230172               Patient Reversed               Patient Reversed
# 4091  230173  Patient - Fast Track Protocol  Patient - Fast Track Protocol
# 4092  230174              Nerve block in OR              Nerve block in OR
# 4093  230176       IUC Stabilization Device       IUC Stabilization Device
# 4094  230177             CRRT - Filter Type             CRRT - Filter Type
#
#               linksto              category unitname     param_type  \
# 0         chartevents               General      NaN           Text
# 1      datetimeevents                   ADT      NaN  Date and time
# 2         chartevents   Routine Vital Signs      bpm        Numeric
# 3         chartevents                Alarms      bpm        Numeric
# 4         chartevents                Alarms      bpm        Numeric
# ...               ...                   ...      ...            ...
# 4090  procedureevents  3-Significant Events      NaN      Processes
# 4091  procedureevents  3-Significant Events      NaN      Processes
# 4092  procedureevents  3-Significant Events      NaN      Processes
# 4093      chartevents                 GI/GU      NaN       Checkbox
# 4094      chartevents              Dialysis      NaN           Text
#
#       lownormalvalue  highnormalvalue
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
# ...              ...              ...
# 4090             NaN              NaN
# 4091             NaN              NaN
# 4092             NaN              NaN
# 4093             NaN              NaN
# 4094             NaN              NaN
#
# [4095 rows x 9 columns]

# %%
abp_df = labevents_df[labevents_df['label'].str.startswith('Arterial Blood Pressure mean', na=False)]

# Display the result
display(abp_df)
# Out:
#    itemid                         label abbreviation      linksto  \
# 8  220052  Arterial Blood Pressure mean         ABPm  chartevents
#
#               category unitname param_type  lownormalvalue  highnormalvalue
# 8  Routine Vital Signs     mmHg    Numeric             NaN              NaN

# %%
temp_df = pd.read_csv(r"../01_MimicIV/CSV/Exports/o04_icu_chartevent.csv")

# %%
display(temp_df)
# Out:
#          subject_id   hadm_id   stay_id  \
# 0          10004733  27411876  39635619
# 1          10004733  27411876  39635619
# 2          10004733  27411876  39635619
# 3          10004733  27411876  39635619
# 4          10004733  27411876  39635619
# ...             ...       ...       ...
# 8530606    19999987  23865745  36195440
# 8530607    19999987  23865745  36195440
# 8530608    19999987  23865745  36195440
# 8530609    19999987  23865745  36195440
# 8530610    19999987  23865745  36195440
#
#                                            first_careunit  \
# 0        Medical/Surgical Intensive Care Unit (MICU/SICU)
# 1        Medical/Surgical Intensive Care Unit (MICU/SICU)
# 2        Medical/Surgical Intensive Care Unit (MICU/SICU)
# 3        Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4        Medical/Surgical Intensive Care Unit (MICU/SICU)
# ...                                                   ...
# 8530606                               Trauma SICU (TSICU)
# 8530607                               Trauma SICU (TSICU)
# 8530608                               Trauma SICU (TSICU)
# 8530609                               Trauma SICU (TSICU)
# 8530610                               Trauma SICU (TSICU)
#
#                                             last_careunit  \
# 0        Medical/Surgical Intensive Care Unit (MICU/SICU)
# 1        Medical/Surgical Intensive Care Unit (MICU/SICU)
# 2        Medical/Surgical Intensive Care Unit (MICU/SICU)
# 3        Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4        Medical/Surgical Intensive Care Unit (MICU/SICU)
# ...                                                   ...
# 8530606                               Trauma SICU (TSICU)
# 8530607                               Trauma SICU (TSICU)
# 8530608                               Trauma SICU (TSICU)
# 8530609                               Trauma SICU (TSICU)
# 8530610                               Trauma SICU (TSICU)
#
#                       intime              outtime       los  seq_num  \
# 0        2174-12-04 11:28:24  2174-12-12 20:03:01  8.357373        2
# 1        2174-12-04 11:28:24  2174-12-12 20:03:01  8.357373        2
# 2        2174-12-04 11:28:24  2174-12-12 20:03:01  8.357373        2
# 3        2174-12-04 11:28:24  2174-12-12 20:03:01  8.357373        2
# 4        2174-12-04 11:28:24  2174-12-12 20:03:01  8.357373        2
# ...                      ...                  ...       ...      ...
# 8530606  2145-11-02 22:59:00  2145-11-04 21:29:30  1.937847        1
# 8530607  2145-11-02 22:59:00  2145-11-04 21:29:30  1.937847        1
# 8530608  2145-11-02 22:59:00  2145-11-04 21:29:30  1.937847        1
# 8530609  2145-11-02 22:59:00  2145-11-04 21:29:30  1.937847        1
# 8530610  2145-11-02 22:59:00  2145-11-04 21:29:30  1.937847        1
#
#          icd_code  icd_version  caregiver_id            charttime  \
# 0           43491            9        8991.0  2174-12-11 20:00:00
# 1           43491            9        8991.0  2174-12-11 20:00:00
# 2           43491            9        8991.0  2174-12-11 20:00:00
# 3           43491            9        8991.0  2174-12-11 20:00:00
# 4           43491            9        8991.0  2174-12-11 20:00:00
# ...           ...          ...           ...                  ...
# 8530606       431            9           NaN  2145-11-04 10:40:00
# 8530607       431            9           NaN  2145-11-04 10:40:00
# 8530608       431            9           NaN  2145-11-04 10:40:00
# 8530609       431            9           NaN  2145-11-04 10:40:00
# 8530610       431            9           NaN  2145-11-04 10:40:00
#
#                    storetime  itemid  value  valuenum  valueuom  warning
# 0        2174-12-11 21:48:00  220045     81    81.000       bpm      0.0
# 1        2174-12-11 21:48:00  220179    159   159.000      mmHg      0.0
# 2        2174-12-11 21:48:00  220180     99    99.000      mmHg      0.0
# 3        2174-12-11 21:48:00  220181    112   112.000      mmHg      0.0
# 4        2174-12-11 21:48:00  220210     19    19.000  insp/min      0.0
# ...                      ...     ...    ...       ...       ...      ...
# 8530606  2145-11-04 11:28:00  225642    7.3     7.300         %      0.0
# 8530607  2145-11-04 11:28:00  225643   68.6    68.600         %      0.0
# 8530608  2145-11-04 11:28:00  227457    120   120.000      K/uL      1.0
# 8530609  2145-11-04 11:30:00  220734    5.5     5.500     units      0.0
# 8530610  2145-11-04 11:30:00  227471  1.022     1.022       NaN      0.0
#
# [8530611 rows x 19 columns]

# %%
filtered_df = temp_df[['itemid', 'valuenum', 'valueuom']]

# %%
filtered_df = temp_df[temp_df['itemid'] == 220052][['itemid', 'valuenum', 'valueuom']]
display(filtered_df)
# Out:
#          itemid  valuenum valueuom
# 4589     220052     102.0     mmHg
# 4596     220052     102.0     mmHg
# 4640     220052     101.0     mmHg
# 4648     220052     107.0     mmHg
# 4663     220052     119.0     mmHg
# ...         ...       ...      ...
# 8528240  220052      86.0     mmHg
# 8528260  220052      94.0     mmHg
# 8528294  220052      84.0     mmHg
# 8528298  220052      85.0     mmHg
# 8529039  220052      92.0     mmHg
#
# [219384 rows x 3 columns]

# %%
filtered_df = filtered_df.sort_values('valuenum', ascending=False)

# %%
display(filtered_df)
# Out:
#          itemid  valuenum valueuom
# 5757288  220052    1410.0     mmHg
# 1482453  220052    1100.0     mmHg
# 6357711  220052    1085.0     mmHg
# 3572462  220052     667.0     mmHg
# 6529446  220052     361.0     mmHg
# ...         ...       ...      ...
# 375709   220052     -36.0     mmHg
# 912433   220052     -36.0     mmHg
# 444747   220052     -37.0     mmHg
# 5511956  220052     -39.0     mmHg
# 1475160  220052     -40.0     mmHg
#
# [219384 rows x 3 columns]

# %%
# File path
file_path = "../00_Datasets/mimic-iv-3_1/icu/chartevents.csv.gz"

# Chunk size
chunksize = 1000000  # Adjust based on your memory capacity

# Filtered data will be appended here
filtered_chunks = []

# Loop through the file in chunks
for chunk in pd.read_csv(file_path, chunksize=chunksize, compression='gzip', usecols=['subject_id', 'itemid', 'valuenum', 'valueuom']):
    # Filter only rows with itemid == 220052
    filtered_chunk = chunk[chunk['itemid'] == 220052]
    filtered_chunks.append(filtered_chunk)

# Combine all filtered chunks into one DataFrame
result_df = pd.concat(filtered_chunks, ignore_index=True)

# Show a preview
print(result_df.head())

# Optional: Save to CSV
# result_df.to_csv("filtered_chartevents_220052.csv", index=False)
# Out:
#    subject_id  itemid  valuenum valueuom
# 0    10002013  220052      89.0     mmHg
# 1    10002013  220052      73.0     mmHg
# 2    10002013  220052      86.0     mmHg
# 3    10002013  220052      66.0     mmHg
# 4    10002013  220052      80.0     mmHg

# %%
result_df = result_df.sort_values('valuenum', ascending=False)
display(result_df)

# %%
display(result_df)
# Out:
#          subject_id  itemid  valuenum valueuom
# 1562086    15063388  220052  930000.0     mmHg
# 2931144    19524390  220052  117113.0     mmHg
# 1391541    14504850  220052  115123.0     mmHg
# 1370362    14441902  220052  115105.0     mmHg
# 2871240    19329421  220052  108122.0     mmHg
# ...             ...     ...       ...      ...
# 3007319    19738358  220052     -60.0     mmHg
# 749330     12385813  220052     -86.0     mmHg
# 1681133    15452443  220052     -99.0     mmHg
# 1432872    14661924  220052    -100.0     mmHg
# 2317209    17488557  220052    -135.0     mmHg
#
# [3096934 rows x 4 columns]

# %%
# File path
file_path = "../00_Datasets/mimic-iv-3_1/icu/chartevents.csv.gz"

# Chunk size
chunksize = 1000000  # Adjust based on your system's RAM

# Container for filtered data
negative_valuenum_chunks = []

# Process the file in chunks
for chunk in pd.read_csv(file_path, chunksize=chunksize, compression='gzip', usecols=['subject_id', 'itemid', 'value', 'valuenum', 'valueuom']):
    # Drop rows where valuenum is NaN to avoid errors
    chunk = chunk.dropna(subset=['valuenum'])

    # Filter for negative valuenum values
    negative_chunk = chunk[chunk['valuenum'] < 0]
    
    # Append to list
    negative_valuenum_chunks.append(negative_chunk)

# Combine all the negative valuenum rows
result_df = pd.concat(negative_valuenum_chunks, ignore_index=True)

# Display a few rows
print(result_df.head())

# Optional: Save to CSV
# result_df.to_csv("negative_valuenum_chartevents.csv", index=False)
# Out:
#    subject_id  itemid                                              value  \
# 0    10001217  228096  -1 Awakens to voice (eye opening/contact) > 10...
# 1    10001217  228096  -1 Awakens to voice (eye opening/contact) > 10...
# 2    10001843  228096  -2 Light sedation, briefly awakens to voice (e...
# 3    10001843  228096  -1 Awakens to voice (eye opening/contact) > 10...
# 4    10001843  228096  -2 Light sedation, briefly awakens to voice (e...
#
#    valuenum valueuom
# 0      -1.0      NaN
# 1      -1.0      NaN
# 2      -2.0      NaN
# 3      -1.0      NaN
# 4      -2.0      NaN

# %%
result_df = result_df.sort_values('valuenum', ascending=True)
display(result_df)
# Out:
#         subject_id  itemid    value     valuenum  valueuom
# 399075    12424661  229896   -1e+07 -10000000.00     Watts
# 239015    11442414  220277  -951234   -951234.00         %
# 768582    14665633  224162  -897868   -897868.00  insp/min
# 109835    10688510  228005  -601600   -601600.00     ml/hr
# 109827    10688510  228005  -601600   -601600.00     ml/hr
# ...            ...     ...      ...          ...       ...
# 604622    13668411  224746    -0.03        -0.03     cmH2O
# 795831    14816494  224746    -0.03        -0.03     cmH2O
# 846659    15097100  224746    -0.02        -0.02     cmH2O
# 240832    11448985  224746    -0.02        -0.02     cmH2O
# 395171    12394964  224746    -0.01        -0.01     cmH2O
#
# [1660253 rows x 5 columns]
