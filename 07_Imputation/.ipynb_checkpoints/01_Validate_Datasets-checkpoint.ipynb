# %% [markdown]
# # Sprint 1: Foundational Setup
#
# ## Task 1 (CIR-8): Load and Validate all Datasets

# %%
import pandas as pd
import numpy as np
import os
import logging

# Plots
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("logs/CIR-8.log"),
        logging.StreamHandler()
    ]
)

# %%
# CSVs Directory 
data_path = "../04_ANN/CSV/exports/split_set/without_multiple_rows"
all_files = os.listdir(data_path)

logging.info("++++++++++++++++++++++++++++++++++++++++++")
logging.info("Start Loading Dataframes.")

# Load CSVs into a dictionary of dataframes
dataframes = {}
for file in all_files:
    if file.endswith(".csv"):
        var_name = file.replace(".csv", "").replace("-", "_")
        logging.info(f"Loading... -> {file}")
        dataframes[var_name] = pd.read_csv(os.path.join(data_path, file)).astype('float32')

# Log loaded datasets
for var_name, df in dataframes.items():
    globals()[var_name] = df
    logging.info(f"{var_name} loaded successfully with shape {df.shape}")
logging.info("Load Complete.")
logging.info("++++++++++++++++++++++++++++++++++++++++++")
# Out:
# 2025-03-23 01:31:53,384 - INFO - ++++++++++++++++++++++++++++++++++++++++++
# 2025-03-23 01:31:53,387 - INFO - Start Loading Dataframes.
# 2025-03-23 01:31:53,388 - INFO - Loading... -> o1_X_external.csv
# 2025-03-23 01:32:00,228 - INFO - Loading... -> o1_X_test.csv
# 2025-03-23 01:32:00,819 - INFO - Loading... -> o1_X_train.csv
# 2025-03-23 01:32:04,899 - INFO - Loading... -> o1_X_validate.csv
# 2025-03-23 01:32:05,444 - INFO - Loading... -> o1_y_external_los.csv
# 2025-03-23 01:32:05,489 - INFO - Loading... -> o1_y_external_mortality.csv
# 2025-03-23 01:32:05,520 - INFO - Loading... -> o1_y_test_los.csv
# 2025-03-23 01:32:05,531 - INFO - Loading... -> o1_y_test_mortality.csv
# 2025-03-23 01:32:05,536 - INFO - Loading... -> o1_y_train_los.csv
# 2025-03-23 01:32:05,580 - INFO - Loading... -> o1_y_train_mortality.csv
# 2025-03-23 01:32:05,598 - INFO - Loading... -> o1_y_validate_los.csv
# 2025-03-23 01:32:05,610 - INFO - Loading... -> o1_y_validate_mortality.csv
# 2025-03-23 01:32:05,616 - INFO - Loading... -> o2_X_external.csv
# 2025-03-23 01:32:09,220 - INFO - Loading... -> o2_X_test.csv
# 2025-03-23 01:32:09,513 - INFO - Loading... -> o2_X_train.csv
# 2025-03-23 01:32:11,514 - INFO - Loading... -> o2_X_validate.csv
# 2025-03-23 01:32:11,784 - INFO - Loading... -> o2_y_external_los.csv
# 2025-03-23 01:32:11,806 - INFO - Loading... -> o2_y_external_mortality.csv
# 2025-03-23 01:32:11,824 - INFO - Loading... -> o2_y_test_los.csv
# 2025-03-23 01:32:11,831 - INFO - Loading... -> o2_y_test_mortality.csv
# 2025-03-23 01:32:11,836 - INFO - Loading... -> o2_y_train_los.csv
# 2025-03-23 01:32:11,859 - INFO - Loading... -> o2_y_train_mortality.csv
# 2025-03-23 01:32:11,870 - INFO - Loading... -> o2_y_validate_los.csv
# 2025-03-23 01:32:11,877 - INFO - Loading... -> o2_y_validate_mortality.csv
# 2025-03-23 01:32:11,882 - INFO - Loading... -> o3_X_external.csv
# 2025-03-23 01:32:14,248 - INFO - Loading... -> o3_X_test.csv
# 2025-03-23 01:32:14,433 - INFO - Loading... -> o3_X_train.csv
# 2025-03-23 01:32:15,758 - INFO - Loading... -> o3_X_validate.csv
# 2025-03-23 01:32:15,947 - INFO - Loading... -> o3_y_external_los.csv
# 2025-03-23 01:32:15,963 - INFO - Loading... -> o3_y_external_mortality.csv
# 2025-03-23 01:32:15,976 - INFO - Loading... -> o3_y_test_los.csv
# 2025-03-23 01:32:15,982 - INFO - Loading... -> o3_y_test_mortality.csv
# 2025-03-23 01:32:15,985 - INFO - Loading... -> o3_y_train_los.csv
# 2025-03-23 01:32:16,001 - INFO - Loading... -> o3_y_train_mortality.csv
# 2025-03-23 01:32:16,009 - INFO - Loading... -> o3_y_validate_los.csv
# 2025-03-23 01:32:16,015 - INFO - Loading... -> o3_y_validate_mortality.csv
# 2025-03-23 01:32:16,018 - INFO - Loading... -> o4_X_external.csv
# 2025-03-23 01:32:17,803 - INFO - Loading... -> o4_X_test.csv
# 2025-03-23 01:32:17,952 - INFO - Loading... -> o4_X_train.csv
# 2025-03-23 01:32:18,984 - INFO - Loading... -> o4_X_validate.csv
# 2025-03-23 01:32:19,142 - INFO - Loading... -> o4_y_external_los.csv
# 2025-03-23 01:32:19,156 - INFO - Loading... -> o4_y_external_mortality.csv
# 2025-03-23 01:32:19,166 - INFO - Loading... -> o4_y_test_los.csv
# 2025-03-23 01:32:19,171 - INFO - Loading... -> o4_y_test_mortality.csv
# 2025-03-23 01:32:19,176 - INFO - Loading... -> o4_y_train_los.csv
# 2025-03-23 01:32:19,191 - INFO - Loading... -> o4_y_train_mortality.csv
# 2025-03-23 01:32:19,198 - INFO - Loading... -> o4_y_validate_los.csv
# 2025-03-23 01:32:19,203 - INFO - Loading... -> o4_y_validate_mortality.csv
# 2025-03-23 01:32:19,209 - INFO - o1_X_external loaded successfully with shape (234720, 345)
# 2025-03-23 01:32:19,210 - INFO - o1_X_test loaded successfully with shape (15312, 345)
# 2025-03-23 01:32:19,211 - INFO - o1_X_train loaded successfully with shape (122496, 345)
# 2025-03-23 01:32:19,212 - INFO - o1_X_validate loaded successfully with shape (15312, 345)
# 2025-03-23 01:32:19,213 - INFO - o1_y_external_los loaded successfully with shape (234720, 1)
# 2025-03-23 01:32:19,214 - INFO - o1_y_external_mortality loaded successfully with shape (234720, 1)
# 2025-03-23 01:32:19,215 - INFO - o1_y_test_los loaded successfully with shape (15312, 1)
# 2025-03-23 01:32:19,216 - INFO - o1_y_test_mortality loaded successfully with shape (15312, 1)
# 2025-03-23 01:32:19,217 - INFO - o1_y_train_los loaded successfully with shape (122496, 1)
# 2025-03-23 01:32:19,218 - INFO - o1_y_train_mortality loaded successfully with shape (122496, 1)
# 2025-03-23 01:32:19,219 - INFO - o1_y_validate_los loaded successfully with shape (15312, 1)
# 2025-03-23 01:32:19,219 - INFO - o1_y_validate_mortality loaded successfully with shape (15312, 1)
# 2025-03-23 01:32:19,220 - INFO - o2_X_external loaded successfully with shape (117360, 345)
# 2025-03-23 01:32:19,221 - INFO - o2_X_test loaded successfully with shape (7656, 345)
# 2025-03-23 01:32:19,223 - INFO - o2_X_train loaded successfully with shape (61248, 345)
# 2025-03-23 01:32:19,224 - INFO - o2_X_validate loaded successfully with shape (7656, 345)
# 2025-03-23 01:32:19,225 - INFO - o2_y_external_los loaded successfully with shape (117360, 1)
# 2025-03-23 01:32:19,226 - INFO - o2_y_external_mortality loaded successfully with shape (117360, 1)
# 2025-03-23 01:32:19,227 - INFO - o2_y_test_los loaded successfully with shape (7656, 1)
# 2025-03-23 01:32:19,228 - INFO - o2_y_test_mortality loaded successfully with shape (7656, 1)
# 2025-03-23 01:32:19,229 - INFO - o2_y_train_los loaded successfully with shape (61248, 1)
# 2025-03-23 01:32:19,229 - INFO - o2_y_train_mortality loaded successfully with shape (61248, 1)
# 2025-03-23 01:32:19,231 - INFO - o2_y_validate_los loaded successfully with shape (7656, 1)
# 2025-03-23 01:32:19,232 - INFO - o2_y_validate_mortality loaded successfully with shape (7656, 1)
# 2025-03-23 01:32:19,233 - INFO - o3_X_external loaded successfully with shape (78240, 345)
# 2025-03-23 01:32:19,234 - INFO - o3_X_test loaded successfully with shape (5104, 345)
# 2025-03-23 01:32:19,234 - INFO - o3_X_train loaded successfully with shape (40832, 345)
# 2025-03-23 01:32:19,235 - INFO - o3_X_validate loaded successfully with shape (5104, 345)
# 2025-03-23 01:32:19,236 - INFO - o3_y_external_los loaded successfully with shape (78240, 1)
# 2025-03-23 01:32:19,236 - INFO - o3_y_external_mortality loaded successfully with shape (78240, 1)
# 2025-03-23 01:32:19,237 - INFO - o3_y_test_los loaded successfully with shape (5104, 1)
# 2025-03-23 01:32:19,240 - INFO - o3_y_test_mortality loaded successfully with shape (5104, 1)
# 2025-03-23 01:32:19,241 - INFO - o3_y_train_los loaded successfully with shape (40832, 1)
# 2025-03-23 01:32:19,241 - INFO - o3_y_train_mortality loaded successfully with shape (40832, 1)
# 2025-03-23 01:32:19,242 - INFO - o3_y_validate_los loaded successfully with shape (5104, 1)
# 2025-03-23 01:32:19,243 - INFO - o3_y_validate_mortality loaded successfully with shape (5104, 1)
# 2025-03-23 01:32:19,243 - INFO - o4_X_external loaded successfully with shape (58680, 345)
# 2025-03-23 01:32:19,244 - INFO - o4_X_test loaded successfully with shape (3828, 345)
# 2025-03-23 01:32:19,245 - INFO - o4_X_train loaded successfully with shape (30624, 345)
# 2025-03-23 01:32:19,245 - INFO - o4_X_validate loaded successfully with shape (3828, 345)
# 2025-03-23 01:32:19,246 - INFO - o4_y_external_los loaded successfully with shape (58680, 1)
# 2025-03-23 01:32:19,247 - INFO - o4_y_external_mortality loaded successfully with shape (58680, 1)
# 2025-03-23 01:32:19,248 - INFO - o4_y_test_los loaded successfully with shape (3828, 1)
# 2025-03-23 01:32:19,248 - INFO - o4_y_test_mortality loaded successfully with shape (3828, 1)
# 2025-03-23 01:32:19,250 - INFO - o4_y_train_los loaded successfully with shape (30624, 1)
# 2025-03-23 01:32:19,251 - INFO - o4_y_train_mortality loaded successfully with shape (30624, 1)
# 2025-03-23 01:32:19,252 - INFO - o4_y_validate_los loaded successfully with shape (3828, 1)
# 2025-03-23 01:32:19,253 - INFO - o4_y_validate_mortality loaded successfully with shape (3828, 1)
# 2025-03-23 01:32:19,253 - INFO - Load Complete.
# 2025-03-23 01:32:19,255 - INFO - ++++++++++++++++++++++++++++++++++++++++++

# %%
logging.info("++++++++++++++++++++++++++++++++++++++++++")
logging.info("Check Datatypes...")
for name, df in dataframes.items():
    logging.info(f"{name} types:\n{df.dtypes.value_counts()}")
logging.info("Check Complete.")
logging.info("++++++++++++++++++++++++++++++++++++++++++")
# Out:
# 2025-03-23 01:32:23,553 - INFO - ++++++++++++++++++++++++++++++++++++++++++
# 2025-03-23 01:32:23,554 - INFO - Check Datatypes...
# 2025-03-23 01:32:23,557 - INFO - o1_X_external types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,559 - INFO - o1_X_test types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,561 - INFO - o1_X_train types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,563 - INFO - o1_X_validate types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,565 - INFO - o1_y_external_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,567 - INFO - o1_y_external_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,568 - INFO - o1_y_test_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,571 - INFO - o1_y_test_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,573 - INFO - o1_y_train_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,575 - INFO - o1_y_train_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,577 - INFO - o1_y_validate_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,579 - INFO - o1_y_validate_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,581 - INFO - o2_X_external types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,583 - INFO - o2_X_test types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,584 - INFO - o2_X_train types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,587 - INFO - o2_X_validate types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,588 - INFO - o2_y_external_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,591 - INFO - o2_y_external_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,593 - INFO - o2_y_test_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,594 - INFO - o2_y_test_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,596 - INFO - o2_y_train_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,598 - INFO - o2_y_train_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,600 - INFO - o2_y_validate_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,602 - INFO - o2_y_validate_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,604 - INFO - o3_X_external types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,606 - INFO - o3_X_test types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,608 - INFO - o3_X_train types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,610 - INFO - o3_X_validate types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,612 - INFO - o3_y_external_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,614 - INFO - o3_y_external_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,615 - INFO - o3_y_test_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,617 - INFO - o3_y_test_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,619 - INFO - o3_y_train_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,620 - INFO - o3_y_train_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,622 - INFO - o3_y_validate_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,624 - INFO - o3_y_validate_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,625 - INFO - o4_X_external types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,627 - INFO - o4_X_test types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,629 - INFO - o4_X_train types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,632 - INFO - o4_X_validate types:
# float32    345
# Name: count, dtype: int64
# 2025-03-23 01:32:23,633 - INFO - o4_y_external_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,635 - INFO - o4_y_external_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,637 - INFO - o4_y_test_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,639 - INFO - o4_y_test_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,641 - INFO - o4_y_train_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,644 - INFO - o4_y_train_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,646 - INFO - o4_y_validate_los types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,648 - INFO - o4_y_validate_mortality types:
# float32    1
# Name: count, dtype: int64
# 2025-03-23 01:32:23,649 - INFO - Check Complete.
# 2025-03-23 01:32:23,650 - INFO - ++++++++++++++++++++++++++++++++++++++++++

# %%
logging.info("++++++++++++++++++++++++++++++++++++++++++")
logging.info("Calculate missing values...")
for name, df in dataframes.items():
    missing_total = df.isnull().sum().sum()
    missing_cols = df.columns[df.isnull().any()].tolist()
    logging.info(f"{name}: {missing_total} missing values across {len(missing_cols)} columns")
logging.info("Missing values calculation complete.")
logging.info("++++++++++++++++++++++++++++++++++++++++++")
# Out:
# 2025-03-23 01:32:27,924 - INFO - ++++++++++++++++++++++++++++++++++++++++++
# 2025-03-23 01:32:27,925 - INFO - Calculate missing values...
# 2025-03-23 01:32:28,102 - INFO - o1_X_external: 39527616 missing values across 308 columns
# 2025-03-23 01:32:28,117 - INFO - o1_X_test: 1985664 missing values across 292 columns
# 2025-03-23 01:32:28,211 - INFO - o1_X_train: 15876288 missing values across 304 columns
# 2025-03-23 01:32:28,226 - INFO - o1_X_validate: 2007696 missing values across 296 columns
# 2025-03-23 01:32:28,228 - INFO - o1_y_external_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,231 - INFO - o1_y_external_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,233 - INFO - o1_y_test_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,234 - INFO - o1_y_test_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,237 - INFO - o1_y_train_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,239 - INFO - o1_y_train_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,241 - INFO - o1_y_validate_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,243 - INFO - o1_y_validate_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,338 - INFO - o2_X_external: 19763572 missing values across 308 columns
# 2025-03-23 01:32:28,347 - INFO - o2_X_test: 992832 missing values across 292 columns
# 2025-03-23 01:32:28,405 - INFO - o2_X_train: 7938144 missing values across 304 columns
# 2025-03-23 01:32:28,415 - INFO - o2_X_validate: 1003848 missing values across 296 columns
# 2025-03-23 01:32:28,417 - INFO - o2_y_external_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,419 - INFO - o2_y_external_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,421 - INFO - o2_y_test_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,424 - INFO - o2_y_test_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,426 - INFO - o2_y_train_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,428 - INFO - o2_y_train_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,430 - INFO - o2_y_validate_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,432 - INFO - o2_y_validate_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,494 - INFO - o3_X_external: 13175808 missing values across 308 columns
# 2025-03-23 01:32:28,501 - INFO - o3_X_test: 661888 missing values across 292 columns
# 2025-03-23 01:32:28,537 - INFO - o3_X_train: 5292096 missing values across 304 columns
# 2025-03-23 01:32:28,544 - INFO - o3_X_validate: 669232 missing values across 296 columns
# 2025-03-23 01:32:28,546 - INFO - o3_y_external_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,549 - INFO - o3_y_external_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,551 - INFO - o3_y_test_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,552 - INFO - o3_y_test_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,554 - INFO - o3_y_train_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,557 - INFO - o3_y_train_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,560 - INFO - o3_y_validate_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,561 - INFO - o3_y_validate_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,611 - INFO - o4_X_external: 9881900 missing values across 308 columns
# 2025-03-23 01:32:28,616 - INFO - o4_X_test: 496416 missing values across 292 columns
# 2025-03-23 01:32:28,644 - INFO - o4_X_train: 3969072 missing values across 304 columns
# 2025-03-23 01:32:28,650 - INFO - o4_X_validate: 501924 missing values across 296 columns
# 2025-03-23 01:32:28,651 - INFO - o4_y_external_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,653 - INFO - o4_y_external_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,656 - INFO - o4_y_test_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,658 - INFO - o4_y_test_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,660 - INFO - o4_y_train_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,663 - INFO - o4_y_train_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,665 - INFO - o4_y_validate_los: 0 missing values across 0 columns
# 2025-03-23 01:32:28,667 - INFO - o4_y_validate_mortality: 0 missing values across 0 columns
# 2025-03-23 01:32:28,667 - INFO - Missing values calculation complete.
# 2025-03-23 01:32:28,668 - INFO - ++++++++++++++++++++++++++++++++++++++++++

# %%
logging.info("++++++++++++++++++++++++++++++++++++++++++")
logging.info("Calculate unique values.")
for name, df in dataframes.items():
    if 'y_' in name:
        unique_vals = df.nunique()
        logging.info(f"{name} unique target values: {unique_vals.to_dict()}")

logging.info("Unique values calculation complete.")
logging.info("++++++++++++++++++++++++++++++++++++++++++")
# Out:
# 2025-03-23 01:32:30,612 - INFO - ++++++++++++++++++++++++++++++++++++++++++
# 2025-03-23 01:32:30,613 - INFO - Calculate unique values.
# 2025-03-23 01:32:30,619 - INFO - o1_y_external_los unique target values: {'los': 830}
# 2025-03-23 01:32:30,623 - INFO - o1_y_external_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,625 - INFO - o1_y_test_los unique target values: {'los': 319}
# 2025-03-23 01:32:30,627 - INFO - o1_y_test_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,631 - INFO - o1_y_train_los unique target values: {'los': 2548}
# 2025-03-23 01:32:30,634 - INFO - o1_y_train_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,635 - INFO - o1_y_validate_los unique target values: {'los': 319}
# 2025-03-23 01:32:30,637 - INFO - o1_y_validate_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,641 - INFO - o2_y_external_los unique target values: {'los': 830}
# 2025-03-23 01:32:30,643 - INFO - o2_y_external_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,645 - INFO - o2_y_test_los unique target values: {'los': 319}
# 2025-03-23 01:32:30,646 - INFO - o2_y_test_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,649 - INFO - o2_y_train_los unique target values: {'los': 2548}
# 2025-03-23 01:32:30,651 - INFO - o2_y_train_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,654 - INFO - o2_y_validate_los unique target values: {'los': 319}
# 2025-03-23 01:32:30,656 - INFO - o2_y_validate_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,660 - INFO - o3_y_external_los unique target values: {'los': 830}
# 2025-03-23 01:32:30,663 - INFO - o3_y_external_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,665 - INFO - o3_y_test_los unique target values: {'los': 319}
# 2025-03-23 01:32:30,667 - INFO - o3_y_test_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,669 - INFO - o3_y_train_los unique target values: {'los': 2548}
# 2025-03-23 01:32:30,671 - INFO - o3_y_train_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,673 - INFO - o3_y_validate_los unique target values: {'los': 319}
# 2025-03-23 01:32:30,675 - INFO - o3_y_validate_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,678 - INFO - o4_y_external_los unique target values: {'los': 830}
# 2025-03-23 01:32:30,680 - INFO - o4_y_external_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,681 - INFO - o4_y_test_los unique target values: {'los': 319}
# 2025-03-23 01:32:30,683 - INFO - o4_y_test_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,685 - INFO - o4_y_train_los unique target values: {'los': 2548}
# 2025-03-23 01:32:30,687 - INFO - o4_y_train_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,688 - INFO - o4_y_validate_los unique target values: {'los': 319}
# 2025-03-23 01:32:30,690 - INFO - o4_y_validate_mortality unique target values: {'hospital_expire_flag': 2}
# 2025-03-23 01:32:30,692 - INFO - Unique values calculation complete.
# 2025-03-23 01:32:30,693 - INFO - ++++++++++++++++++++++++++++++++++++++++++

# %%
summary = []
for name, df in dataframes.items():
    missing_values = df.isnull().sum().sum()
    missing_cols = df.isnull().any().sum()
    total_cells = df.shape[0] * df.shape[1]
    summary.append({
        'Dataset': name,
        'Shape': df.shape,
        'Total Missing Values': missing_values,
        'Accross Missing Columns': missing_cols,
        'Missing %': 100 * missing_values / total_cells
    })

summary_df = pd.DataFrame(summary)
# Save to file
summary_df.to_csv("CSV/exports/01_dataset_summary.csv", index=False)

# %%
percent = 7

# Dictionary of datasets for iteration
datasets = {
    "o1_X_train": o1_X_train,
    "o2_X_train": o2_X_train,
    "o3_X_train": o3_X_train,
    "o4_X_train": o4_X_train
}

# Loop through each dataset
for name, df in datasets.items():
    missing_percentage_per_row = df.isnull().mean(axis=1) * 100
    missing_rows = (missing_percentage_per_row <= percent).sum()
    total_rows, total_columns = df.shape
    percent_between = (missing_rows * 100) / total_rows

    print(f"\nDataset: {name}")
    print(f"Total Rows: {total_rows}, Total Columns: {total_columns}")
    print(f"Number of rows with missing values up to {percent}%: {missing_rows}")
    print(f"The percentage between total and missing values sets is {percent_between:.2f}%")
# Out:
# Dataset: o1_X_train
# Total Rows: 122496, Total Columns: 345
# Number of rows with missing values up to 7%: 48
# The percentage between total and missing values sets is 0.04%
#
# Dataset: o2_X_train
# Total Rows: 61248, Total Columns: 345
# Number of rows with missing values up to 7%: 24
# The percentage between total and missing values sets is 0.04%
#
# Dataset: o3_X_train
# Total Rows: 40832, Total Columns: 345
# Number of rows with missing values up to 7%: 16
# The percentage between total and missing values sets is 0.04%
#
# Dataset: o4_X_train
# Total Rows: 30624, Total Columns: 345
# Number of rows with missing values up to 7%: 12
# The percentage between total and missing values sets is 0.04%

# %% [markdown]
# ## Task 2 (CIR-9): Analyze Missingness (per row/column)

# %%
missingness_summary = []

for name, df in dataframes.items():
    if not isinstance(df, pd.DataFrame):
        continue
    
    total_cells = df.shape[0] * df.shape[1]
    total_missing = df.isnull().sum().sum()
    
    col_missing = df.isnull().mean() * 100
    row_missing = df.isnull().mean(axis=1) * 100
    
    summary = {
        'Dataset': name,
        'Shape': df.shape,
        'Total Missing Cells': total_missing,
        'Total Missing %': round(100 * total_missing / total_cells, 2),
        'Columns with Missing (%)': (col_missing > 0).sum(),
        'Max % Missing in Row': round(row_missing.max(), 2),
        'Mean % Missing in Row': round(row_missing.mean(), 2),
        'Min % Missing in Row': round(row_missing.min(), 2)
    }
    missingness_summary.append(summary)

# Create DataFrame for summary
missingness_df = pd.DataFrame(missingness_summary)

# Sort by most missing
missingness_df.sort_values("Total Missing %", ascending=False, inplace=True)

# Save to file
missingness_df.to_csv("CSV/exports/02_missingness_summary.csv", index=False)

# Show top rows, I have leave out the y_ files which are labels
display(missingness_df.head(16))
# Out:
#           Dataset          Shape  Total Missing Cells  Total Missing %  \
# 0   o1_X_external  (234720, 345)             39527616            48.81
# 12  o2_X_external  (117360, 345)             19763572            48.81
# 36  o4_X_external   (58680, 345)              9881900            48.81
# 24  o3_X_external   (78240, 345)             13175808            48.81
# 27  o3_X_validate    (5104, 345)               669232            38.01
# 3   o1_X_validate   (15312, 345)              2007696            38.01
# 15  o2_X_validate    (7656, 345)              1003848            38.01
# 39  o4_X_validate    (3828, 345)               501924            38.01
# 25      o3_X_test    (5104, 345)               661888            37.59
# 1       o1_X_test   (15312, 345)              1985664            37.59
# 13      o2_X_test    (7656, 345)               992832            37.59
# 37      o4_X_test    (3828, 345)               496416            37.59
# 26     o3_X_train   (40832, 345)              5292096            37.57
# 2      o1_X_train  (122496, 345)             15876288            37.57
# 14     o2_X_train   (61248, 345)              7938144            37.57
# 38     o4_X_train   (30624, 345)              3969072            37.57
#
#     Columns with Missing (%)  Max % Missing in Row  Mean % Missing in Row  \
# 0                        308                 89.28                  48.81
# 12                       308                 89.28                  48.81
# 36                       308                 89.28                  48.81
# 24                       308                 89.28                  48.81
# 27                       296                 78.84                  38.01
# 3                        296                 78.84                  38.01
# 15                       296                 78.84                  38.01
# 39                       296                 78.84                  38.01
# 25                       292                 80.00                  37.59
# 1                        292                 80.00                  37.59
# 13                       292                 80.00                  37.59
# 37                       292                 80.00                  37.59
# 26                       304                 81.16                  37.57
# 2                        304                 81.16                  37.57
# 14                       304                 81.16                  37.57
# 38                       304                 81.16                  37.57
#
#     Min % Missing in Row
# 0                  13.91
# 12                 13.91
# 36                 13.91
# 24                 13.91
# 27                  9.28
# 3                   9.28
# 15                  9.28
# 39                  9.28
# 25                 10.43
# 1                  10.43
# 13                 10.43
# 37                 10.43
# 26                  6.96
# 2                   6.96
# 14                  6.96
# 38                  6.96

# %% [markdown]
# ## Task 3 (CIR-10): Visualize Missingness

# %%
# Create output folder
output_dir = "figures/task3_missingness"
os.makedirs(output_dir, exist_ok=True)

# Functions for plotting
def plot_missing_heatmap(
    df, title, max_rows=200, save_path=None, suffix_filter='(Min)', cmap='Blues'
):
    filtered_cols = [col for col in df.columns if col.endswith(suffix_filter)]
    df_filtered = df[filtered_cols].head(max_rows)

    plt.figure(figsize=(16, 6))
    sns.heatmap(df_filtered.isnull(), cbar=False, cmap=cmap, yticklabels=False,
                linecolor='lightgrey', linewidths=0.001)

    plt.title(f"Missing Data Heatmap – First {max_rows} Rows\n({suffix_filter}) – {title}",
              fontsize=14, weight='bold')
    plt.xlabel("Features", fontsize=12)
    plt.ylabel("Rows", fontsize=12)
    plt.xticks(fontsize=8, rotation=90)
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.close()


def plot_column_missing_bar(
    df, title, save_path=None, top_n=40, suffix_filter='(Min)', color='#3E8ED0'
):
    filtered_cols = [col for col in df.columns if col.endswith(suffix_filter)]
    missing_perc = df[filtered_cols].isnull().mean() * 100
    missing_perc = missing_perc[missing_perc > 0].sort_values(ascending=False).head(top_n)

    plt.figure(figsize=(10, 0.4 * len(missing_perc)))
    ax = missing_perc.plot(kind='barh', color=color)

    plt.title(f"Top {len(missing_perc)} Features with Missing Values\n({suffix_filter}) – {title}",
              fontsize=14, weight='bold')
    plt.xlabel("Percentage Missing", fontsize=12)
    plt.ylabel("Feature", fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=8)
    plt.grid(axis='x', linestyle='--', linewidth=0.5)
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.close()


# Filter only X datasets from the summary
top_datasets = missingness_df[
    (~missingness_df['Dataset'].str.startswith('y_')) &
    (missingness_df['Dataset'].isin(dataframes.keys()))
].head(16)['Dataset'].tolist()

# Generate plots
for dataset_name in top_datasets:
    df = dataframes.get(dataset_name)
    if df is not None:
        print(f"Generating plots for: {dataset_name}")
        heatmap_path = os.path.join(output_dir, f"{dataset_name}_heatmap.png")
        barplot_path = os.path.join(output_dir, f"{dataset_name}_barplot.png")
        
        plot_missing_heatmap(df, dataset_name, save_path=heatmap_path)
        plot_column_missing_bar(df, dataset_name, save_path=barplot_path)
    else:
        print(f"Dataset not found in dataframes: {dataset_name}")
# Out:
# Generating plots for: o1_X_external
# Generating plots for: o2_X_external
# Generating plots for: o4_X_external
# Generating plots for: o3_X_external
# Generating plots for: o3_X_validate
# Generating plots for: o1_X_validate
# Generating plots for: o2_X_validate
# Generating plots for: o4_X_validate
# Generating plots for: o3_X_test
# Generating plots for: o1_X_test
# Generating plots for: o2_X_test
# Generating plots for: o4_X_test
# Generating plots for: o3_X_train
# Generating plots for: o1_X_train
# Generating plots for: o2_X_train
# Generating plots for: o4_X_train
